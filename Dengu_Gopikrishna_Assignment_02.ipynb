# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Monday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (25 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
#
# (3) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (4) Collect all the information of the 904 narrators in the Densho Digital Repository.
#
# (5)**Collect a total of 10000 reviews** of the top 100 most popular software from G2 and Capterra.

# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen


narrators_data = []


main_url = "https://ddr.densho.org/narrators/?page={}"


counter = 0
max_narrators = 904


for page_num in range(1, 46):
    link1 = Request(main_url.format(page_num), headers={'User-Agent': 'Mozilla/5.0'})
    url1 = urlopen(link1)
    data1 = url1.read()
    data1_soup = BeautifulSoup(data1, 'html.parser')

    print(f"*** Processing Page {page_num} ***")  # Print page number for tracking

    # Iterate through each narrator on the page
    for narrator_link in data1_soup.find_all('h4'):
        if counter >= max_narrators:
            break

        link2 = Request(narrator_link.a.get('href'), headers={'User-Agent': 'Mozilla/5.0'})
        url2 = urlopen(link2)
        data2 = url2.read()
        data2_soup = BeautifulSoup(data2, 'html.parser')

        # Extract narrator name and biography
        try:
            narrator = data2_soup.find("div", attrs={'class': 'col-sm-8 col-md-8'})
            name = narrator.h1.text.strip().replace('"', "") if narrator.h1 else ""
            bio = narrator.p.text.strip() if narrator.p else ""
        except:
            name, bio = "", ""

        # Store extracted data
        narrators_data.append({'Narrator_Name': name, 'Bio': bio})
        counter += 1  # Increase counter

    if counter >= max_narrators:
        break  # Stop if we reach the desired number


df = pd.DataFrame(narrators_data)

# Save DataFrame to CSV
df.to_csv('narrators_data.csv', index=False, encoding='utf-8')

print(f"✅ Total narrators processed: {len(narrators_data)}")
print("📁 Data saved as 'narrators_data.csv'")
# Out:
# *** Processing Page 1 ***
# *** Processing Page 2 ***
# *** Processing Page 3 ***
# *** Processing Page 4 ***
# *** Processing Page 5 ***
# *** Processing Page 6 ***
# *** Processing Page 7 ***
# *** Processing Page 8 ***
# *** Processing Page 9 ***
# *** Processing Page 10 ***
# *** Processing Page 11 ***
# *** Processing Page 12 ***
# *** Processing Page 13 ***
# *** Processing Page 14 ***
# *** Processing Page 15 ***
# *** Processing Page 16 ***
# *** Processing Page 17 ***
# *** Processing Page 18 ***
# *** Processing Page 19 ***
# *** Processing Page 20 ***
# *** Processing Page 21 ***
# *** Processing Page 22 ***
# *** Processing Page 23 ***
# *** Processing Page 24 ***
# *** Processing Page 25 ***
# *** Processing Page 26 ***
# *** Processing Page 27 ***
# *** Processing Page 28 ***
# *** Processing Page 29 ***
# *** Processing Page 30 ***
# *** Processing Page 31 ***
# *** Processing Page 32 ***
# *** Processing Page 33 ***
# *** Processing Page 34 ***
# *** Processing Page 35 ***
# *** Processing Page 36 ***
# *** Processing Page 37 ***
# ✅ Total narrators processed: 904
# 📁 Data saved as 'narrators_data.csv'

# %% [markdown]
# # Question 2 (15 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Ensure required NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

# Load the dataset
df = pd.read_csv('narrators_data.csv')


print(df.head())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
#            Narrator_Name                                                Bio
# 0           Kay Aiko Abe  Nisei female. Born May 9, 1927, in Selleck, Wa...
# 1                Art Abe  Nisei male. Born June 12, 1921, in Seattle, Wa...
# 2  Sharon Tanagi Aburano  Nisei female. Born October 31, 1925, in Seattl...
# 3        Toshiko Aiboshi  Nisei female. Born July 8, 1928, in Boyle Heig...
# 4      Douglas L. Aihara  Sansei male. Born March 15, 1950, in Torrance,...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
def remove_noise(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)

# Apply function to Bio column
df['Cleaned_Bio'] = df['Bio'].astype(str).apply(remove_noise)


print(df[['Bio', 'Cleaned_Bio']].head())
# Out:
#                                                  Bio  \
# 0  Nisei female. Born May 9, 1927, in Selleck, Wa...
# 1  Nisei male. Born June 12, 1921, in Seattle, Wa...
# 2  Nisei female. Born October 31, 1925, in Seattl...
# 3  Nisei female. Born July 8, 1928, in Boyle Heig...
# 4  Sansei male. Born March 15, 1950, in Torrance,...
#
#                                          Cleaned_Bio
# 0  Nisei female Born May   in Selleck Washington ...
# 1  Nisei male Born June   in Seattle Washington G...
# 2  Nisei female Born October   in Seattle Washing...
# 3  Nisei female Born July   in Boyle Heights Cali...
# 4  Sansei male Born March   in Torrance Californi...

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# Apply function
df['Cleaned_Bio'] = df['Cleaned_Bio'].apply(remove_numbers)


print(df[['Bio', 'Cleaned_Bio']].head())
# Out:
#                                                  Bio  \
# 0  Nisei female. Born May 9, 1927, in Selleck, Wa...
# 1  Nisei male. Born June 12, 1921, in Seattle, Wa...
# 2  Nisei female. Born October 31, 1925, in Seattl...
# 3  Nisei female. Born July 8, 1928, in Boyle Heig...
# 4  Sansei male. Born March 15, 1950, in Torrance,...
#
#                                          Cleaned_Bio
# 0  Nisei female Born May   in Selleck Washington ...
# 1  Nisei male Born June   in Seattle Washington G...
# 2  Nisei female Born October   in Seattle Washing...
# 3  Nisei female Born July   in Boyle Heights Cali...
# 4  Sansei male Born March   in Torrance Californi...

# %%
import nltk
nltk.download('punkt')  # For tokenization
nltk.download('stopwords')  # For stop words list
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def remove_stopwords(text):
    # Tokenize using split() and lowercase the text
    words = text.lower().split()
    stop_words = set(nltk.corpus.stopwords.words('english'))  # Set of stopwords
    return " ".join([word for word in words if word not in stop_words])

# %%
df['Cleaned_Bio'] = df['Cleaned_Bio'].str.lower()

# Show sample output
print(df[['Bio', 'Cleaned_Bio']].head())
# Out:
#                                                  Bio  \
# 0  Nisei female. Born May 9, 1927, in Selleck, Wa...
# 1  Nisei male. Born June 12, 1921, in Seattle, Wa...
# 2  Nisei female. Born October 31, 1925, in Seattl...
# 3  Nisei female. Born July 8, 1928, in Boyle Heig...
# 4  Sansei male. Born March 15, 1950, in Torrance,...
#
#                                          Cleaned_Bio
# 0  nisei female born may   in selleck washington ...
# 1  nisei male born june   in seattle washington g...
# 2  nisei female born october   in seattle washing...
# 3  nisei female born july   in boyle heights cali...
# 4  sansei male born march   in torrance californi...

# %%
import nltk
nltk.download('punkt', download_dir='/root/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

def apply_stemming(text):

    words = text.split()  # Split by whitespace
    return " ".join([stemmer.stem(word) for word in words])

# Apply function
df['Cleaned_Bio'] = df['Cleaned_Bio'].apply(apply_stemming)

# Show sample output
print(df[['Bio', 'Cleaned_Bio']].head())
# Out:
#                                                  Bio  \
# 0  Nisei female. Born May 9, 1927, in Selleck, Wa...
# 1  Nisei male. Born June 12, 1921, in Seattle, Wa...
# 2  Nisei female. Born October 31, 1925, in Seattl...
# 3  Nisei female. Born July 8, 1928, in Boyle Heig...
# 4  Sansei male. Born March 15, 1950, in Torrance,...
#
#                                          Cleaned_Bio
# 0  nisei femal born may in selleck washington spe...
# 1  nisei male born june in seattl washington grew...
# 2  nisei femal born octob in seattl washington fa...
# 3  nisei femal born juli in boyl height californi...
# 4  sansei male born march in torranc california g...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def apply_lemmatization(text):
    # Use split() instead of word_tokenize
    words = text.split()
    return " ".join([lemmatizer.lemmatize(word) for word in words])

# Apply function
df['Cleaned_Bio'] = df['Cleaned_Bio'].apply(apply_lemmatization)

# Show sample output
print(df[['Bio', 'Cleaned_Bio']].head())
# Out:
#                                                  Bio  \
# 0  Nisei female. Born May 9, 1927, in Selleck, Wa...
# 1  Nisei male. Born June 12, 1921, in Seattle, Wa...
# 2  Nisei female. Born October 31, 1925, in Seattl...
# 3  Nisei female. Born July 8, 1928, in Boyle Heig...
# 4  Sansei male. Born March 15, 1950, in Torrance,...
#
#                                          Cleaned_Bio
# 0  nisei femal born may in selleck washington spe...
# 1  nisei male born june in seattl washington grew...
# 2  nisei femal born octob in seattl washington fa...
# 3  nisei femal born juli in boyl height californi...
# 4  sansei male born march in torranc california g...

# %%
df.to_csv('cleaned_narrators_data.csv', index=False, encoding='utf-8')

print("✅ Data cleaning completed. Saved as 'cleaned_narrators_data.csv'")
# Out:
# ✅ Data cleaning completed. Saved as 'cleaned_narrators_data.csv'

# %% [markdown]
# # Question 3 (15 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import spacy
import pandas as pd
from collections import Counter

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Load the cleaned data from the CSV file
df = pd.read_csv('cleaned_narrators_data.csv')

# Extract the cleaned text from the 'Cleaned_Bio' column
cleaned_narrators_data = df['Cleaned_Bio'].iloc[0]

# Process the text using spaCy
doc = nlp(cleaned_narrators_data)

# 1. Parts of Speech (POS) Tagging
pos_counts = Counter()
for token in doc:
    pos_counts[token.pos_] += 1

# Print POS counts
print("Parts of Speech (POS) Counts:")
print(f"Nouns (NOUN): {pos_counts['NOUN']}")
print(f"Verbs (VERB): {pos_counts['VERB']}")
print(f"Adjectives (ADJ): {pos_counts['ADJ']}")
print(f"Adverbs (ADV): {pos_counts['ADV']}")

# 2. Constituency Parsing and Dependency Parsing
# Dependency Parsing
print("\nDependency Parsing Trees:")
for sent in doc.sents:
    print("\nSentence:", sent.text)
    for token in sent:
        print(f"Word: {token.text}, Dependency: {token.dep_}, Head: {token.head.text}")



# For each sentence, print the constituency tree (use Benepar after installation)
print("\nConstituency Parsing Trees:")
for sent in doc.sents:

    print("Constituency parsing tree can be visualized with Benepar library")

# 3. Named Entity Recognition (NER)
ner_counts = Counter()
for ent in doc.ents:
    ner_counts[ent.label_] += 1

# Print NER counts
print("\nNamed Entity Recognition (NER) Counts:")
for entity, count in ner_counts.items():
    print(f"{entity}: {count}")

# Example to explain Dependency Parsing and Constituency Parsing:
print("\nExplanation of Parsing Trees with One Example Sentence:")

example_sentence = "Apple was founded by Steve Jobs in Cupertino in 1976."

# Dependency Parsing of the example sentence
doc_example = nlp(example_sentence)
print("\nDependency Parsing of Example Sentence:")
for token in doc_example:
    print(f"Word: {token.text}, Dependency: {token.dep_}, Head: {token.head.text}")
# Out:
# Parts of Speech (POS) Counts:
# Nouns (NOUN): 11
# Verbs (VERB): 3
# Adjectives (ADJ): 2
# Adverbs (ADV): 0
#
# Dependency Parsing Trees:
#
# Sentence: nisei femal born may selleck washington spent much childhood beaverton oregon father own farm influenc earli age parent convers christian world war ii remov portland assembl center oregon minidoka concentr camp idaho war work establish success volunt program feed homeless seattl washington
# Word: nisei, Dependency: compound, Head: femal
# Word: femal, Dependency: nsubj, Head: selleck
# Word: born, Dependency: acl, Head: femal
# Word: may, Dependency: aux, Head: selleck
# Word: selleck, Dependency: compound, Head: washington
# Word: washington, Dependency: nsubj, Head: spent
# Word: spent, Dependency: ROOT, Head: spent
# Word: much, Dependency: amod, Head: beaverton
# Word: childhood, Dependency: compound, Head: beaverton
# Word: beaverton, Dependency: dobj, Head: spent
# Word: oregon, Dependency: compound, Head: father
# Word: father, Dependency: appos, Head: beaverton
# Word: own, Dependency: ccomp, Head: spent
# Word: farm, Dependency: compound, Head: influenc
# Word: influenc, Dependency: nmod, Head: convers
# Word: earli, Dependency: compound, Head: parent
# Word: age, Dependency: compound, Head: parent
# Word: parent, Dependency: compound, Head: convers
# Word: convers, Dependency: dobj, Head: own
# Word: christian, Dependency: compound, Head: center
# Word: world, Dependency: compound, Head: center
# Word: war, Dependency: compound, Head: center
# Word: ii, Dependency: compound, Head: center
# Word: remov, Dependency: compound, Head: center
# Word: portland, Dependency: compound, Head: center
# Word: assembl, Dependency: compound, Head: center
# Word: center, Dependency: compound, Head: concentr
# Word: oregon, Dependency: compound, Head: concentr
# Word: minidoka, Dependency: compound, Head: concentr
# Word: concentr, Dependency: appos, Head: convers
# Word: camp, Dependency: conj, Head: spent
# Word: idaho, Dependency: compound, Head: war
# Word: war, Dependency: compound, Head: work
# Word: work, Dependency: nsubj, Head: establish
# Word: establish, Dependency: ccomp, Head: camp
# Word: success, Dependency: compound, Head: volunt
# Word: volunt, Dependency: compound, Head: program
# Word: program, Dependency: compound, Head: feed
# Word: feed, Dependency: dobj, Head: establish
# Word: homeless, Dependency: compound, Head: seattl
# Word: seattl, Dependency: appos, Head: feed
# Word: washington, Dependency: npadvmod, Head: establish
#
# Constituency Parsing Trees:
# Constituency parsing tree can be visualized with Benepar library
#
# Named Entity Recognition (NER) Counts:
# PERSON: 1
# GPE: 4
# NORP: 1
# EVENT: 1
#
# Explanation of Parsing Trees with One Example Sentence:
#
# Dependency Parsing of Example Sentence:
# Word: Apple, Dependency: nsubjpass, Head: founded
# Word: was, Dependency: auxpass, Head: founded
# Word: founded, Dependency: ROOT, Head: founded
# Word: by, Dependency: agent, Head: founded
# Word: Steve, Dependency: compound, Head: Jobs
# Word: Jobs, Dependency: pobj, Head: by
# Word: in, Dependency: prep, Head: founded
# Word: Cupertino, Dependency: pobj, Head: in
# Word: in, Dependency: prep, Head: founded
# Word: 1976, Dependency: pobj, Head: in
# Word: ., Dependency: punct, Head: founded

# %% [markdown]
# # **Following Questions must answer using AI assitance**

# %% [markdown]
# #Question 4 (20 points).

# %% [markdown]
# Q4. (PART-1)
# Web scraping data from the GitHub Marketplace to gather details about popular actions. Using Python, the process begins by sending HTTP requests to multiple pages of the marketplace (1000 products), handling pagination through dynamic page numbers. The key details extracted include the product name, a short description, and the URL.
#
#  The extracted data is stored in a structured CSV format with columns for product name, description, URL, and page number. A time delay is introduced between requests to avoid server overload. ChatGPT can assist by helping with the parsing of HTML, error handling, and generating reports based on the data collected.
#
#  The goal is to complete the scraping within a specified time limit, ensuring that the process is efficient and adheres to GitHub’s usage guidelines.
#
# (PART -2)
#
# 1.   **Preprocess Data**: Clean the text by tokenizing, removing stopwords, and converting to lowercase.
#
# 2. Perform **Data Quality** operations.
#
#
# Preprocessing:
# Preprocessing involves cleaning the text by removing noise such as special characters, HTML tags, and unnecessary whitespace. It also includes tasks like tokenization, stopword removal, and lemmatization to standardize the text for analysis.
#
# Data Quality:
# Data quality checks ensure completeness, consistency, and accuracy by verifying that all required columns are filled and formatted correctly. Additionally, it involves identifying and removing duplicates, handling missing values, and ensuring the data reflects the true content accurately.

# %% [markdown]
# Github MarketPlace page:
# https://github.com/marketplace?type=actions

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from urllib.error import HTTPError
import json
import pandas as pd
import numpy as np
import re

marketplace_url = "https://github.com/marketplace?type=actions"
total_pages = 500

# Create an empty list to store product data
product_data = []

for page_number in range(1, total_pages + 1):
    request_link = Request(marketplace_url, headers={'User-Agent': 'Mozilla/5.0'})
    response_url = urlopen(request_link)
    page_data = response_url.read()
    soup = BeautifulSoup(page_data).find('div', class_="mt-4 marketplace-common-module__marketplace-list-grid--vCk7D")

    marketplace_items = soup.find_all('div', class_="position-relative border rounded-2 d-flex marketplace-common-module__marketplace-item--MohVH gap-3 p-3")

    for item in marketplace_items:
        product_name_container = item.find('div', class_="d-flex flex-justify-between flex-items-start gap-3")
        product_name = product_name_container.find('a').text
        product_info = item.find('p').text
        # Append product details to the product_data list
        product_data.append([product_name, product_info])
        print(product_name)
        print(product_info)


df_products = pd.DataFrame(product_data, columns=["Product Name", "Product Info"])

# Save the DataFrame to a CSV file
csv_filename = "Github_marketplace_products.csv"
df_products.to_csv(csv_filename, index=False, encoding="utf-8")

print(f"CSV file '{csv_filename}' has been created successfully!")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# ...
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# TruffleHog OSS
# Scan Github Actions with TruffleHog
#
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
#
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
#
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
#
# Gosec Security Checker
# Runs the gosec security checker
#
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
#
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
#
# Checkout
# Checkout a Git repository at a particular version
#
# SSH Remote Commands
# Executing remote ssh commands
#
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
#
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
#
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
#
# Build and push Docker images
# Build and push Docker images with Buildx
#
# GH Release
# Github Action for creating Github Releases
#
# run-digger
# Manage terraform collaboration
#
# Rebuild Armbian
# Build Armbian Linux
#
# GitHub Script
# Run simple scripts using the GitHub client
#
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
#
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
#
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
#
# CSV file 'Github_marketplace_products.csv' has been created successfully!

# %% [markdown]
# #Question 5 (20 points)
#
# PART 1:
# Web Scrape  tweets from Twitter using the Tweepy API, specifically targeting hashtags related to subtopics (machine learning or artificial intelligence.)
# The extracted data includes the tweet ID, username, and text.
#
# Part 2:
# Perform data cleaning procedures
#
# A final data quality check ensures the completeness and consistency of the dataset. The cleaned data is then saved into a CSV file for further analysis.
#
#
# **Note**
#
# 1.   Follow tutorials provided in canvas to obtain api keys. Use ChatGPT to get the code. Make sure the file is downloaded and saved.
# 2.   Make sure you divide GPT code as shown in tutorials, dont make multiple requestes.

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.11/dist-packages (4.15.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2025.1.31)

# %%
import tweepy

#  keys and tokens
api_key = 'LEUfNWAANi1QGqbFbrymuYeDd'
api_key_secret = 'bTqKo8wPM75hBHNNtWdPdlPw7r5AQFlwVsDfSir8rUUlXCq589'
access_token = '1892088892427468802-fAc8wavNBjTuINmG77livRitO3VK3H'
access_token_secret = 'AAAAAAAAAAAAAAAAAAAAAAeHzQEAAAAA4gwxNFEUSMcC%2BnI%2FUPYZX8g6ocM%3DlshMAd4oD4ubYBdJG82SsUYByrccB5XLn2DeakNRklXqnR6K6h'

# Authenticate with Twitter
auth = tweepy.OAuth1UserHandler(
    consumer_key=api_key,
    consumer_secret=api_key_secret,
    access_token=access_token,
    access_token_secret=access_token_secret
)
api = tweepy.API(auth)

# %%
import tweepy

# bearer token
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAAeHzQEAAAAA4gwxNFEUSMcC%2BnI%2FUPYZX8g6ocM%3DlshMAd4oD4ubYBdJG82SsUYByrccB5XLn2DeakNRklXqnR6K6h')


# I have used same query as explained in the class, But now i am exceeded to run new query
query = "#llm -is:retweet"
tweets = client.search_recent_tweets(query=query, tweet_fields=["created_at", "text", "author_id"], max_results=100)

# Printing tweets
for tweet in tweets.data:
    print(f"User: {tweet.author_id}, Tweet: {tweet.text}")
# Out:
# User: 1633336812105084932, Tweet: Dobby: The best LLM personality, outperforming SOTA models. Compare with Llama 70B: https://t.co/lcFI4d7mhX #AI #LLM for a couple of seconds
# Dobby: the ultimate LLM personality—outshining SOTA. Thanks, @confident_ai. Compare: https://t.co/lcFI4d7mhX
# #AI #LLM
#
# @SentientAGI
# User: 7365972, Tweet: sn-news: #open #ai #ml #llm Researchers open source Sky-T1, a ‘reasoning’ AI model that can be trained for less than $450 https://t.co/0SpdH3rCVY
# User: 1574016451006107648, Tweet: Introducing Root Judge, a powerful mid-sized LLM that enables reliable and customizable LLM system evaluations. Trained on 384 AMD Radeon Instinct™ MI250X GPUs using the LUMI Supercomputer. #LLM #LLMs #evaluation #llm_as_a_judge #llama @RootSignals
# Check: https://t.co/VBiCck3jM8 https://t.co/UhOXzSwjD5
# User: 109488608, Tweet: El lado del mal - Perplexity Pro Deep Research: Gratis para todos los clientes de Movistar https://t.co/g6UjCKsysq #Perplexity #Movistar #Telefónica #IA #AI #GenAI #LLM #DeepResearch https://t.co/ATuoABm6wk
# User: 1890662331782426625, Tweet: 「On Context Utilization in Summarization with Large Language Models」
#
# LLMは100kトークンを超えるような長い入力コンテキストを扱えるようになったが、質問応答では、言語モデルは入力コンテキストの活用にばらつきがある。
#
# https://t.co/DY1ZLXL64O
#
# #論文 #LLM #エンジニア #スタートアップ
# User: 1847148591112163328, Tweet: The Attention Mechanism That Skips the Chit-Chat!!🚋
# 👉https://t.co/4tYbRSkIYF
#
# #DeepSeek #attention #llm
#
# DeepSeek dropped a new paper—Natively trainable Sparse Attention (NSA), a new sparse attention mechanism that integrates hardware-optimized design with a hierarchical sparse… https://t.co/4dCxmRtttH https://t.co/JHNHhCc2IK
# User: 717265953986228224, Tweet: DeepSeek in my Engineer’s Eyes @rsstabs https://t.co/b8gvrByaiq #llm-applications #genai #deepseek #generative-ai-tools #machine-learning
# User: 50274262, Tweet: Qwen #LLM ... What it really means https://t.co/FchthtRpey
# User: 550268745, Tweet: SGPT-3.0 #LLM #Grok3 #SGPT https://t.co/16zam6f49j https://t.co/aVTfKGkI7F
# User: 1477134637394661378, Tweet: This domain name  is for sale.
# https://t.co/kh2NrPtLSy
#
# #ai #jais #LLM  #domain #GPT
# #Arab #Arabic #Dubai #ABUDhabi
# @AI_Arabic1 @Algorand_Arabic
#  #Domains #domainsales #jaisai
# #DomainNameForSae #chatbot
# @G42ai @core42_ai @Inception_AI https://t.co/kJHm8ZOqho
# User: 1810919973583474692, Tweet: W&amp;B、LLM開発の強力な味方！実験管理、ハイパーパラメータ調整、モデル評価が簡単。ダッシュボードで進捗把握、チーム共有も◎。Traces機能でデバッグ効率UP。基盤モデル構築、ファインチューニング、アプリ開発に最適。今後はCI/CD自動化も活用予定。#WeightsAndBiases #LLM #AI
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Like human brains, large language models reason about diverse data in a general way« https://t.co/XJlMNzcaRX #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »MIT spinout maps the body’s metabolites to uncover the hidden drivers of disease« https://t.co/141LyhjiZ0 #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1875413617530781696, Tweet: Agent AI, który sam podejmuje decyzje za Ciebie! Jak to działa w praktyce? 😱
#
# Wbijaj, żeby odsłuchać odcinek z @_overment  na:
# 🔴 YouTube: https://t.co/UKPeCY7CoO
#
# #ai #sztucznainteligencja #llm https://t.co/UH2sZbHqGy
# User: 17866447, Tweet: Need web/mobile clients to hit #LLM inference APIs directly, but providers don't offer an API where a server can acquire an ephemeral API key that expires in 15 mins or less. I shouldn't need to write up a proxy for this need. /cc @OpenAI @GoogleCloudTech @GroqInc @Azure @ollama
# User: 1879765053941133312, Tweet: How to grade LLMs? 5 essential metrics:
#
# 1️⃣ Perplexity: Measures uncertainty.
# 2️⃣ BLEU: Compares to reference.
# 3️⃣ ROUGE: Evaluates summarization.
# 4️⃣ Humans: Expert judgment.
# 5️⃣ Task Specific: Goal performance.
#
# #LLM #Evaluation #Metrics
# User: 835102956, Tweet: Agentic AI Layers
# Source:@brijpandeyji
# #GenerativeAI #GenAI #LLM #LargeLanguageModel #DataScience #AI #NaturalLanguageProcessing #data #DataScience #BigData #datascientist #dataanalytics #datamanagement #datamining #dataengineer #agenticai #ArtificialIntelligence #MachineLearning https://t.co/ku5zhPTm7w
# User: 1566993608863281152, Tweet: Today's the day!🚀Join #openEuler and researchers from @uniofedinburgh, and @PKU1898, for an insightful workshop on the future of #operatingsystems, #heterogeneous systems, #LLM, and cutting-edge techs.
# Register now: https://t.co/9C0T43j1FO
# #opensource #OS https://t.co/9Sck0taXKo
# User: 1369521936640868352, Tweet: An #AI that speaks your language, understands your data, and delivers relevant, reliable insights. 🤖💭 - the power of Tailor-Made Local #LLM with @RedHat ® AI
#
# We build a model that works for you, without settling on generic #AI.
#
# #LocalLLM #hallucination #GenAI https://t.co/KrHGVMA1Ye
# User: 1419669296007946240, Tweet: 📢 Claude 3.5 Sonnet Just Dropped! 🚀
# 🔹 2x faster than Claude 3 Opus
# ⚡ Beats GPT-4o in benchmarks
# 🚀 Free on https://t.co/CQ9dr5JJXp &amp; API access
# ❓ Is this the new speed king?
# Source: TechCrunch
# #AI #LLM #Anthropic
# User: 550268745, Tweet: SGPT-3.0 #LLM #Grok3 #SGPT https://t.co/MQTEGw2ixC https://t.co/VfPKKUAoy1
# User: 1401518462, Tweet: Livebook 上で日本語テキスト埋め込みモデル Ruri によるテキスト検索を実装する（Ollama 利用） https://t.co/8cvyhAKGuF #Qiita #MyElixirStatus #LLM @nakaji573より
# User: 1401518462, Tweet: Livebook 上で日本語テキスト埋め込みモデル Ruri によるテキスト検索を実装する https://t.co/Mhd157atv7 #Qiita #MyElixirStatus #LLM @nakaji573より
# User: 94096043, Tweet: LLM系AIの社内浸透が進めば進むほど【甲】AIを使いこなし躍進する人、【乙】AIに振り回さる人、【丙】AI完全依存で自己喪失の人、の差が際立ってくる。甲乙丙いずれも組織に居続けるのでマネジメントの人としての能力が求められるようになる。#LLM #ChatGPT #Copilot #FAQ
# User: 1884044639407333379, Tweet: 🔥 My New Video Episode 2! 🔥
#
# Learn AI &amp; Become an AI Engineer 🚀
#
# 📹 AI Products | Core Principles | Large Language Models
#
# 👉 Watch Now: https://t.co/sH3sWD5IhW
#
# #AI #AIEngineer #LearnAI #MachineLearning #TechEducation #Urdu #Hindi #LLM #DeepLearning
# User: 46404397, Tweet: イーロンマスク「地球で最も賢いAI」と宣言ーーxAI、最新AIモデル「Grok 3」を正式リリース　有料会員向けに提供開始 | https://t.co/NtfQqftWUK  #LLM #search #reasoning #NLP #AI https://t.co/dYFPopxN5N
# User: 2596664952, Tweet: Amazon's COSMO, an AI system, will revolutionize online shopping. This "Common Sense Knowledge Generation" system powers Amazon Search, bridging the gap between queries &amp; intent.
#
# #amazon #geo #genai #llm #performancemarketing #cosmo https://t.co/E98bCH1mkp
# User: 1609568625463291905, Tweet: #Pienso 是一个 B2B 人工智能平台，它利用文本数据进行洞察力生成、文档智能和内容管理。 #AI #LLM https://t.co/b5ewNHTStZ
# User: 111317745, Tweet: Rio Yokota of Institute of Science Tokyo (new name for Titech) giving an update on #LLM work using #supercomputers in Japan at #MW25NZ mixed with an excellent overall discussion of wider  international #AI evolution and advances
#
# #HPC https://t.co/YH4oLAtbkY
# User: 60280565, Tweet: 実践的なプロンプトエンジニアリング手法を解説
# https://t.co/tl8z7G47a5
#
# #プロンプトエンジニアリング #LLM
# User: 1532781042137972736, Tweet: This MCP server allows automation of interactions with WordPress sites through the WordPress REST API using JSON-RPC 2.0 protocol.
#
# https://t.co/7AiSgQslkI
#
# #mcp #AI #llm #lrm #WordPress  #Automation
# User: 15446273, Tweet: ⚡ AI just got faster!
# Speculative Decoding speeds up LLMs by 2x–3x using a draft model + verification model approach.
# ✅ Faster AI responses ✅ Retains accuracy ✅ Integrated in LM Studio 0.3.10
# 🔗 Read more:
#  https://t.co/fb6bZLk7xs
#
#  #LLM #SpeculativeDecoding #LMStudio https://t.co/Yuzi742O9C
# User: 1874787231145295872, Tweet: Grok 3 tops LM Marina leaderboard! Smart, "mostly uncensored", text-to-video, future "Super Grok" sub. Direct Twitter data access, truth-focused, Colossus-trained. Passed vibe check with Spel code. #AI #Grok3 #LLM
# User: 1333957305704955904, Tweet: 🎉Amazing work! 🎓We’re delighted that #myCobot280 M5 could support your study on vision control using large-scale vision-language models.  Keep pushing boundaries! 🤖Keep up the amazing work!🚀Learn more👉https://t.co/NqtmLEG2FU #Robotics #TechInnovation #AI #LLM #M5Stack https://t.co/QW20X4ANY0
# User: 1195283868732944384, Tweet: Staffing Magazine更新！
# 本日は、「AI開発の新手法『LIMO』、数百件のデータで実現する高性能化」について解説しています。
# ぜひチェックしてみてください！
#  #LIMO #LLM #AIProfessional
# https://t.co/tKnGIMHRYz
# User: 92477308, Tweet: xAI, '세계에서 가장 똑똑한' Grok-3 출시...추론 모델 'DeepSearch'도 발표 (출처:aitimes)
# -xAI는 17일 X(트위터) 이벤트를 통해 그록-3를 발표.
# -세계 최대의 AI 데이터센터 '콜로서스'에서 훈련된 것으로, 각종 벤치마크에서 현존 최강인 오픈AI 및 딥시크를 능가.
# #grok3 #llm #xai #wonwizard https://t.co/dE8LedvfT0
# User: 5323232, Tweet: “「AIの利用・開発に関する契約チェックリスト」を取りまとめました （METI/経済産業省）” https://t.co/PXlkLsSMXy #ai #LLM #契約 #d
# User: 1621447081717030913, Tweet: Hack infiltration and recovery services? Inbox me for help. #llm #largelanguagemodels #ai #rag #finetuning #machinelearning #แถลงข่าวงานบอล55ปีช่อง3 #ピッコマでポイ活 https://t.co/rImvTVwpUq
# User: 1888332907401359360, Tweet: 🚀 A Comprehensive Overview of LLMs in DETAIL!
# Written by top researchers &amp; students, this paper covers everything about Large Language Models in an easy-to-understand way.
# 📖 Read here 👉 https://t.co/GuqCas0uTA
#
# #AI #MachineLearning #LLM #DeepLearning  @Setters_Ai
# User: 147149941, Tweet: 【論文】自己適応型LLMの新時代『Self-adaptive LLMs』について簡単に纏めてみました
# https://t.co/O9aOEytCjC
# #論文 #AI #LLM
# User: 1640297006, Tweet: Sometimes you have to be careful what you ask for - what are the consequences of using #GenerativeAI ? As they say - moderation is key - the same applies to #GenAI usage ! https://t.co/0uCtxu53Ym #innovation #disruption #ArtificialIntelligence #LLM #AI #AIinnovation
# User: 46404397, Tweet: GPT-4oより高性能うたう「Grok 3」マスク氏のxAIがリリース。ウェブ版とiOSアプリ版で提供 | テクノエッジ TechnoEdge #LLM #search #reasoning #AI https://t.co/pim2itNof6
# User: 46404397, Tweet: マスク氏のｘＡＩ、対話型生成ＡＩ「グロック３」をリリース | ロイター #chat #LLM #NLP #AI https://t.co/MwfAyxjJU6
# User: 318276161, Tweet: How does AI understand you?
#
# Tokenization!
# Text breaks into "tokens" (words/sub-words), each getting a unique ID from a vocabulary. Like looking up a word, this ID is how LLMs understand.
# Tokenization: Text -&gt; Tokens -&gt; IDs (pre-defined vocab). Simple!
# #LLM #Tokenization #NLP
# User: 1879765053941133312, Tweet: LLMs boosting support? 5 powerful use cases:
#
# 1️⃣ Chatbots: Automated convos.
# 2️⃣ FAQs: Quick answers.
# 3️⃣ Sentiment: Understand emotion.
# 4️⃣ Personalize: Tailored exp.
# 5️⃣ Auto Tickets: Streamline workflow.
#
# #LLM #CustomerService #AI
# User: 147149941, Tweet: 【論文】自己適応型LLMの新時代『Self-adaptive LLMs』について簡単に纏めてみました
# https://t.co/O9aOEyua9a
# #論文 #AI #LLM
# User: 76204432, Tweet: Agree, incredibly useful - the right amount of detail across the entire #LLM pipeline. I can't believe this is offered gratis from @karpathy . . . hyper-targeted knowledge diffusion, wow. https://t.co/SZ5hRYKw1S
# User: 988959080088678400, Tweet: ウェビナー開催決定！
# 「生成AI x テキスト分析の進化 〜 LLMによる最新のテキスト特徴量とビジネスでの活用法 〜」
# 3月27日(木) 12:00～13:00
# 視聴方法:Zoom (参加無料)
#
# https://t.co/GCtgpdXy13
#
# #dotdata #生成AI #データ活用 #データ分析 #テキスト分析 #DX推進 #LLM #特徴量 #自然言語処理 #NLP https://t.co/i8wjidcC66
# User: 1870134778189754371, Tweet: Pipelines optimize LLMs by handling data flow, tokenization, training, and inference efficiently. They enhance scalability, performance, and adaptability for AI applications. #LLM #AI #MachineLearning https://t.co/8MUhXD1qdC
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Humane’s AI Pin is dead« https://t.co/lQK0UDOzUr #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1640297006, Tweet: Wow - can #GenerativeAI help us be happier within ourselves &amp; satisfy our human urges ? These are strong claims - we're never going to stop using #GenAI - are we ? https://t.co/T3shkD4F16 #innovation #disruption #LLM #SLM #AgenticAI #AIinnovation #EthicalAI #TrustworthyAI l
# User: 416378712, Tweet: REVISTA DIGITAL DE FEBRERO 2025
# Economía, Gerencia y Tecnología
# Sin ningún registro
#
# ➡️Léala ahora: https://t.co/tJeOyLRi47  ✅
#
# #IA #ML #DL #Cloud #LLM #BI
# #Technology #DigitalTransformation #Management
# #Economy #Profit #Psychology  #Robot
# #Crypto #Fintech #Banking #data https://t.co/VrsIjXw6UR
# User: 632304408, Tweet: I just published a tutorial on how to use Temperature and Top P in Google AI Studio to control AI creativity and vocabulary. Hope you find it useful!
#
# #LLM #AI
#
# https://t.co/OQSQR3g6mx
# User: 1198841976264806400, Tweet: 7/ The experiments were conducted on Llama-3.2-1B-Instruct. More insights to come as I refine these techniques.
#
# What are your thoughts on manipulating activation directions in LLMs? Let’s discuss! #AI #LLM #MachineLearning #AISecurity #MLunlearning #MachineUnlearning
# User: 1198841976264806400, Tweet: 4/n Example of feature ablation:
#
# ❓ Prompt: Where is California?
# ✅ Baseline: California is a state in the western US.
# ❌ Ablated: California can refer to different things depending on context… (but never states where it is)
#
# #AI #NLP #LLM
# User: 1198841976264806400, Tweet: I’ve been playing around with LLM activations and found some interesting insights.
# Here’s what I found:🧵
# 1/n
# #AI #MachineLearning #LLM #Interpretability #alignment #opensource #AGI
# User: 1719074185346211840, Tweet: @pmarca @AravSrinivas Hence it seems safe to guess, M. @AravSrinivas, that you've implemented a proprietary ideological filter to make a #OpenSource Chinese #LLM, which would have no intrinsic biases on its own (those would be introduced in the training materials), acceptable to right-wing politics.
# User: 1882102517124698112, Tweet: @deepeval  did a great job framing a systematic approach for end tö end #RAG evaluation
# https://t.co/waM0ZDhTDh
# However can we do better?
# Can Hyperpameters optimization help ❓️
# Check this discussion to get more insights
# https://t.co/YO2MAfITzY
# #LLM https://t.co/JdPtd92GjK
# User: 4903766958, Tweet: IBM is stepping up the game! New small vision LM - Granite Vision 3.1, a 2B param model - with exceptional performance on visual document understanding. 📄🔍
#
# This model was trained by fine-tuning a Granite LLM (Granite-3.1-2B-Instruct) with both image and text.
#
# #research #llm… https://t.co/6PRqcO5NLX https://t.co/RgAlBbhVIx
# User: 1679879671889145856, Tweet: Totday's Portfolio Summary
# #StockMarkets #Arduino #ESP32 #Raspberrypi #Chihuahua #Stocks #Hodl #Python #Alpaca #Ollama #LLama3 #LLM #GPT https://t.co/upR1jozSD6
# User: 1885428507859111936, Tweet: The rise of LLMs is revolutionizing how we learn, but recent research from The Wharton School shows that their efficiency may come at a cost: shallower knowledge. Active learning through web searches leads to deeper understanding and more unique insights.
# #AI #LLM #Learning #Edu
# User: 1820880317173116928, Tweet: RAG systems hallucinate more than you think.
# Without PROPER evaluation, you’re:
# ❌ Wasting $$$ on irrelevant data retrieval
# ❌ Ignoring ‘confidently wrong’ answers
# ❌ Missing critical gaps in real-time
# But TRIAD flips the script. ⚡️
# #LLM #GenAI https://t.co/jMArMiAgC3
# User: 1089951017670770688, Tweet: Mhm, yeah. AI will take jobs away from software engineers. haha so funny.
#
# They'll assist everyone, they won't be as capable as the human brain.
#
# #AI #llm #tech https://t.co/NbB0EO4cJf
# User: 1838068239038828544, Tweet: @ilyasut is right. Scaling Law is hitting its limit. #AI #LLM #Grok3
# User: 7981712, Tweet: Let’s free #LLM reasoning with unbiased open source model weights! ❤️📚 https://t.co/V6sxgj011d
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Safe Superintelligence, Ilya Sutskever’s AI startup, is reportedly close to raising roughly $1B« https://t.co/i9NklCzmnv #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1713369924637437952, Tweet: @AutismCapital @balajis It's also quite false, M. @AutismCapital, because the #LLM is not intelligent and does not understand English, nor indeed any human language. @grok and @ChatGPTapp and @cohere and all the rest of these things are *not thinking*, remember? They can't tell truth from falsehood.
# User: 193660103, Tweet: Curious: Do we have benchmarks measuring Western #LLM biases? 🧐
#
# My observation: topics like climate, energy, gender, health tend toward left-leaning narratives.
#
# Even Grok shows this pattern - https://t.co/KohOmSkSmT (base &amp; proprietary, all negative = left leaning) #ai https://t.co/NwGCgVl0LY
# User: 87696926, Tweet: 🔥 #GitHub February Updates: Developer Experience Improvements 🔥
#
# #ai #llm #coding 🧵 👇
#
# 🤖 #GPT4o #Copilot model now in public preview - trained on 275k+ repositories across 30+ programming languages https://t.co/GLQ3EmZF4B
# User: 1554336728822886400, Tweet: Try this dobby out. its funnier them most of The LLM's out there. It is very refreshing and engaing.
#
# Dobby is your that friend who can bitch about infront of you.
#
# #Dobby #Sentient  #LLM https://t.co/CSd7rWaWPK
# User: 1577693815778992132, Tweet: What is next in Radiology Generative AI? #LLM #AIAgent and beyond!! Great talk by @woojinrad @SocietyAbdRad @MoffittNews #SAR25 https://t.co/lJVFZJm7VV https://t.co/maMPx9K3Gy
# User: 1713369924637437952, Tweet: @imPenny2x @RobotJunkyard72 M. @imPenny2x, how is a hammer (a hand tool) like an #LLM?
#
# You can actually hurt yourself using a hammer, you know. It requires skill to use a hammer and not everyone can do it properly. Hammering nails is something you don't know how to do, Penny (i.e. it's hard work.)
#
# ~Chara
# User: 875641, Tweet: English is the new programming language!!!
# #PromptEngineering #AutonomousCoding #CoPilot #AI #GenAI #LLM https://t.co/oIucDy62PI
# User: 1550008074169192450, Tweet: 🟣 KAIST and DeepAuto #AI Researchers Propose InfiniteHiP: A Game-Changing Long-Context #LLM Framework for 3M-Token Inference on a Single GPU
#
# Read more 👇👇
# https://t.co/IswWOQY2VP https://t.co/gtZwSgbcBS
# User: 1254326877822558208, Tweet: Koel-TTS from NVIDIA tackles LLM speech hallucinations using preference alignment + classifier-free guidance. Achieves SOTA intelligibility (0.51% CER) with less training data.
# https://t.co/CiJgHzHDB4
#
# #SpeechAI #LLM #TTS https://t.co/1dICzpACD2
# User: 1619484833243140103, Tweet: New Blog: Challenging the Hype: Why AI’s Path to General Intelligence Needs a Rethink - Part One
#
# Read our Blog: https://t.co/CxKhU8Mn5l
#
# #AISecurity #AIThirdParty #AICompliance #LLM #AGI #AIForGood https://t.co/Smayl7mC9v
# User: 4493091144, Tweet: 📚✨ Successful Pre-Synopsis Submission at CPJ Campus! ✨📚
#
# On 17th February 2025, CPJ College proudly conducted the Pre-Synopsis Submission for our LL.M. students, featuring the esteemed Dr. Anuj Kumar Vaksha, Professor at GGSIPU.
#
# #LLM #ResearchDevelopment #CPJCampus https://t.co/mMKGHl89AE
# User: 94647328, Tweet: @VadimYuryev @VadimYuryev Great Video: your enthusiasm is infectious, i am seeing the brilliance of Æ #UNIFIEDMEMORY pool as opposed to separate hardware for the CPU &amp; GPU tasks. To be able to run an independent #LLM on hardware which requires 20+W &amp; fits in your palm.
# https://t.co/AgN2PDpp9Z https://t.co/lN6CIkvN7W
# User: 1861488376450318337, Tweet: At NVIDIA, our collaboration with @tech_mahindra has been a testament to generative AI innovation, pioneering first dialect based Hindi #LLM Nemotron-4-Mini-Hindi-4B model using NVIDIA's stack. Watch the video.
# https://t.co/avkW63LdMM https://t.co/6IOG9J3aiv
# User: 1222060734634504192, Tweet: 🚀 #SQL Measures? In #BI?! 😯
# Timbr's Semantic Metric Store makes metrics simple.
#
# ✨ No joins, no redundant calculations!
# 🔍 Reusable, consistent metrics across tools
# ⚡️ 90% faster dashboard delivery
# 🤖 #LLM integration for accurate insights
#
# 👉 https://t.co/u5Y5rjEpKU
# User: 1248453468064370691, Tweet: The #Delegated #Chain o #Thought #Architecture. #DCoT #architecture #decouples #reasoning from #execution in #LLM by #centralizing reasoning in "#modulith" n #delegating execution #tasks 2 #specialized #modules🤖
#
# #ReAct #Toolformer #AI👾 #Tek_nikel54🤖
# https://t.co/zioBP23Mlp https://t.co/p0gA3UjZG6
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Thinking Machine Labs is ex-OpenAI CTO Mira Murati’s new startup« https://t.co/iCfcYfH3Bs #AIagent #AI #ML #NLP #LLM #GenAI
# User: 706183262398320640, Tweet: Not all shipments are created equal! 🚗💡 Our AI-powered priority system flags high-priority orders based on urgency, deadlines, and complexity—ensuring they move seamlessly through the system. #shipcarssmarter https://t.co/vibstQyrdI
# #carshipping #ai #llm #automotivelogistics https://t.co/vdNi1rWakc
# User: 1713369924637437952, Tweet: @elonmusk @charliekirk11 @TeamTrump @X @DOGE @imPenny2x @WholeMarsBlog @natemcgrady @GOP @RonaldReagan @jpodhoretz @p_m_robinson @DavidLimbaugh @JohnStossel @shaunmmaguire @lexfridman @pegobry_en @TheRabbitHole84 @charlesmurray I had roaring intellectual arguments, "dialectic" arguments that would cause M. @ConceptualJames or M. @curtis_yarvin or M. @realchrisrufo to faint dead away (then they'd revive and fart out ten #LLM books on the teensy little taste they had) with a Marxist Chilean exile.
#
# ~Chara
# User: 344923471, Tweet: If your AI model isn’t giving you the right answers, the problem might not be the model—it might be how you’re using it.
#
# #Deepseek #LLM #AI #MachineLearning #NaturalLanguageProcessing https://t.co/pWMtfXzXad
# User: 1830702321480642560, Tweet: The Next Frontier in AI: Consumer-Centric Applications for Real-World Impact https://t.co/Lmw2I3NSsC #AI #LLM... Like and Follow for more QuantumBytz updates! Subscribe to our Telegram channel @quantumbytz.
# User: 127444271, Tweet: AI tools can refine your LLM personal statement, but remember—authenticity is key. Admissions teams want YOUR voice, not a generic response. Use AI ethically and stay true to your story.
#
# #LLMGuide #LLM #LegalEducation #LLMStatement
#
# https://t.co/XUOMfzzCB6
# User: 1610501809151381505, Tweet: 🚀Can your language model think strategically?
# 🧠 SMART: Boosting LM self-awareness to reduce Tool Overuse &amp; optimize reasoning!
# 🌐 https://t.co/zJQM7GcEFd
# 📊 https://t.co/oeogaduCLB
# Smaller models, bigger brains. Smarter tool use, better results! 🔥 #AI #LLM https://t.co/KKsVgA8ViY
# User: 89028456, Tweet: Unlock #LLM inference with auto-scaling on @AWS EKS ✨
#
# ✅ Set up EFA networking &amp; EFS storage with NVLink-connected H100 GPUs on P5.48xlarge
# ✅ Deploy multi-node Triton Inference Server + TRT-LLM to scale LLaMa 3.1 405B models
# ✅ Use LeaderWorkerSet &amp; Prometheus metrics for… https://t.co/cVYXJaESIV https://t.co/LnDKbMk3Xd
# User: 295681476, Tweet: Will software developers soon lose their jobs to AI? It’s not the end of programming but “the end of programming”https://t.co/ohx49e6COe  #AI #datascience #machinelearning #LLM #code #coding
# User: 1045700375997747203, Tweet: 🚀 Free Course: Agentic AI Essentials for Managers &amp; Professionals 💼
#
# 👨‍💼 Empower your team, gain actionable insights, and stay ahead in the AI-powered world!
#
# 👉 Join Now: https://t.co/4GDwi20CA9
#
# #FreeCourse #AIForBusiness #LLM #Managers #Innovation #AILeadership
# User: 21229836, Tweet: AI is transforming the way we work—but it’s also reshaping the threat landscape.
#
# Evolving Solutions is here to help you stay ahead of the threats.
#
# Read the 5 Must-Know Insights into the Evolving 2025 Security Landscape: https://t.co/0jmAR5r38i #Cybersecurity #AI #LLM https://t.co/muJiXS2co3
# User: 1330900913238716416, Tweet: New FrigidStealer Malware Targets macOS Users via Fake Browser Updates
#
# https://t.co/2QAfAYRA5r
#
# #llm #gpt #ai #cybersecurity #malware #threatdetection #genai  #soc #cyberdefense #threatintel #threats #chatgpt #gemini #llama #nlp #artificialintelligence #digitaltransformation https://t.co/mzttCPKBei
# User: 1700230407369695232, Tweet: أول USB في العالم يحمل نموذج لغوي كبير! يمكنك الآن توليد نصوص مباشرة من الذاكرة الفلاشية.
#
# #LLM #AI #USB #innovation
# https://t.co/pf6RkbFlac
# User: 21754023, Tweet: 💡 Grok 3: il nuovo modello AI di xAI è pronto a sfidare OpenAI
#
# https://t.co/Fcq1kwvokG
#
# #ai #blog #elonmusk #gemini #grok #ia #llm #news #openai #picks #tech #tecnologia #xai @elonmusk @xai
# User: 3559557437, Tweet: @ephremishac introduces the first public Syriac HTR model on @Transkribus helping make Syriac manuscripts more accessible. #digitalhumanities #SyriacStudies #history #HTR #Coding
# #llm
#
# https://t.co/NjnbkaeVhw
# User: 19656981, Tweet: Karpathy tested Grok 3. It matches GPT in reasoning tasks. Solid progress but still needs work on humor. #AI #LLM #Tech https://t.co/vdUXv3QFQ5
# User: 361631391, Tweet: Need to fine-tune a public LLM with your company’s data? Speeding these tasks can help you build your AI solution sooner. How @Dell PowerEdge R7615 servers with @Broadcom 100GbE NICs can help accelerate the process: https://t.co/svUw9TfV5Y #AI #LLM https://t.co/3sofhHVG7H
# User: 1719074185346211840, Tweet: @elonmusk @imPenny2x @WholeMarsBlog @ajtourville @WallStreetMav @themarketswork @cb_doge @mayemusk @SawyerMerritt @WalterIsaacson @DogecoinNorway @AutismCapital @rpoo Sudden rises in #stocks or #cryptocurrencies are easily publicized—the process must surely be almost automatic now, even without the "help" of @OpenAI or @grok or some other #LLM slush generator to crank out #news #content according to simple formulae, e.g. #StockMarket spikes.
# User: 2863292385, Tweet: Our latest #AI &amp; #DataEngineering case study showcases how we helped a financial company enhance data extraction accuracy and scalability using cutting-edge #LLM optimization and #AzureAI.
#
# Read the full Case:https://t.co/AIox48m41j
#
# Get a quote today: https://t.co/6wGoAURQVt https://t.co/MWsQpuSNay

# %%
import pandas as pd

# list to store tweet data
tweet_data = []

if tweets.data:
    for tweet in tweets.data:
        tweet_data.append({
            'tweet_id': tweet.id,
            'author_id': tweet.author_id,
            'created_at': tweet.created_at,
            'text': tweet.text
        })


df = pd.DataFrame(tweet_data)


print(df)


df.to_csv("tweets_csv", index=False)
# Out:
#                tweet_id            author_id                created_at  \
# 0   1892095836839956836  1633336812105084932 2025-02-19 06:16:15+00:00
# 1   1892093508346880020              7365972 2025-02-19 06:07:00+00:00
# 2   1892091762023317995  1574016451006107648 2025-02-19 06:00:04+00:00
# 3   1892090363415756880            109488608 2025-02-19 05:54:30+00:00
# 4   1892089823545974850  1890662331782426625 2025-02-19 05:52:21+00:00
# ..                  ...                  ...                       ...
# 95  1891900670401294391           3559557437 2025-02-18 17:20:44+00:00
# 96  1891898788635345362             19656981 2025-02-18 17:13:15+00:00
# 97  1891895544622014733            361631391 2025-02-18 17:00:22+00:00
# 98  1891893520564355405  1719074185346211840 2025-02-18 16:52:19+00:00
# 99  1891892174804889706           2863292385 2025-02-18 16:46:58+00:00
#
#                                                  text
# 0   Dobby: The best LLM personality, outperforming...
# 1   sn-news: #open #ai #ml #llm Researchers open s...
# 2   Introducing Root Judge, a powerful mid-sized L...
# 3   El lado del mal - Perplexity Pro Deep Research...
# 4   「On Context Utilization in Summarization with ...
# ..                                                ...
# 95  @ephremishac introduces the first public Syria...
# 96  Karpathy tested Grok 3. It matches GPT in reas...
# 97  Need to fine-tune a public LLM with your compa...
# 98  @elonmusk @imPenny2x @WholeMarsBlog @ajtourvil...
# 99  Our latest #AI &amp; #DataEngineering case stu...
#
# [100 rows x 4 columns]

# %% [markdown]
# # Mandatory question

# %% [markdown]
# Provide Your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment

# %% [markdown]
# I was able to apply my data science skills, particularly text preprocessing like stemming and lemmatization, thanks to this interesting assignment.
#
# Challenges:
#
# Managing missing resources, such as the NLTK punkt tokenizer, was the biggest challenge and needed a lot of effort to get through.
#
# Features I Enjoyed:
#
# Getting the data cleaned and converted successfully was satisfying.
#
# Time Taken to Complete:
#
# Although getting past the NLTK issues took longer than anticipated, the given time was mostly sufficient.

# %% [markdown]
# # Write your response below
# Fill out survey and provide your valuable feedback.
#
# https://docs.google.com/forms/d/e/1FAIpQLSd_ObuA3iNoL7Az_C-2NOfHodfKCfDzHZtGRfIker6WyZqTtA/viewform?usp=dialog
